# %% [markdown]
# ![image.png](attachment:b868ecc6-6413-47f7-96bf-d1bd6d390afa.png)

# %% [markdown]
# open() function is used to open the file.
#
# different modes of opening a file are:
# Read Only (‘r’) : Open text file for reading. The handle is positioned at the beginning of the file. If the file does not exists, raises the I/O error. This is also the default mode in which a file is opened.
#
# Read and Write (‘r+’): Open the file for reading and writing. The handle is positioned at the beginning of the file. Raises I/O error if the file does not exist.
#
# Write Only (‘w’) : Open the file for writing. For the existing files, the data is truncated and over-written. The handle is positioned at the beginning of the file. Creates the file if the file does not exist.
#
# Write and Read (‘w+’) : Open the file for reading and writing. For an existing file, data is truncated and over-written. The handle is positioned at the beginning of the file.
#
# Append Only (‘a’): Open the file for writing. The file is created if it does not exist. The handle is positioned at the end of the file. The data being written will be inserted at the end, after the existing data.
#
# Append and Read (‘a+’) : Open the file for reading and writing. The file is created if it does not exist. The handle is positioned at the end of the file. The data being written will be inserted at the end, after the existing data.

# %% [markdown]
# ![image.png](attachment:20b2bd70-c503-41b4-ab89-18017d7dc5a6.png)

# %% [markdown]
# close functio is used to close the file which is open.
# closing of file is important because if files are not closed then changes made in file will be not visible until the file is closed.

# %% [markdown]
# ![image.png](attachment:dfd3794d-5a38-4635-9a24-c5ff39696e8d.png)

# %%
f=open("text1.txt",'w')
f.write("I want to become a data science")
f.close()
f=open("text1.txt",'r')
f.read()
# Out:
# 'I want to become a data science'

# %% [markdown]
# ![image.png](attachment:b77ca579-911f-4c5d-b070-9d8c649b1fdf.png)

# %%
# read() reades the file contents
f=open("text.txt",'r')
print(f.read())

# readline() reades the lines of file contents at once time.
f.seek(0)
print(f.readline())

#readlines() reades the all the lines of file contents at once 
print(f.readlines())
# Out:
# Data Science Masters course is highly curated and uniquely designed according to the latest industry standards.
# This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language.
# Data Science Masters course is highly curated and uniquely designed according to the latest industry standards.
#
# ...

# %% [markdown]
# ![image.png](attachment:feb41f4b-cb2b-4685-83eb-db2a15c08d07.png)

# %% [markdown]
# In Python, with statement is used in exception handling to make the code cleaner and much more readable.
# Advantage of with statements is that we have to not close the file it automatically closes the file

# %% [markdown]
# ![image.png](attachment:d25bcb2b-4025-4c85-9890-5c3904281f97.png)

# %%
# write statement writes the whole string at once
with open("text1.txt",'w') as f:
    f.write("this is file")
# writelines take the list as input
    f.writelines(["pwskills\n","is\n","best\n","course"])
